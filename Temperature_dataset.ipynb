# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/mneha/OneDrive/Documents/GitHub/DSData/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df['station'] = df['station'].fillna(df['station'].mode()[0])

# %%
df.isnull().sum()
# Out:
# station              0
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df['Date'] = df['Date'].fillna(df['Date'].mode()[0])

# %%
df.isnull().sum()
# Out:
# station              0
# Date                 0
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# dtype: object

# %%
df['Present_Tmax'] = df['Present_Tmax'].fillna(df['Present_Tmax'].mean())

# %%
df.isnull().sum()
# Out:
# station              0
# Date                 0
# Present_Tmax         0
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df['Present_Tmin'] = df['Present_Tmax'].fillna(df['Present_Tmin'].mean())

# %%
df['LDAPS_RHmin'] = df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())

# %%
df['LDAPS_RHmax'] = df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].mean())

# %%
df['LDAPS_Tmax_lapse'] = df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())

# %%
df['LDAPS_Tmin_lapse'] = df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())

# %%
df['LDAPS_WS'] = df['LDAPS_WS'].fillna(df['LDAPS_WS'].mean())

# %%
df['LDAPS_LH'] = df['LDAPS_LH'].fillna(df['LDAPS_LH'].mean())

# %%
df['LDAPS_CC1'] = df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].mean())

# %%
df['LDAPS_CC2'] = df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].mean())

# %%
df['LDAPS_CC3'] = df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].mean())

# %%
df['LDAPS_CC4'] = df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].mean())

# %%
df['LDAPS_PPT1'] = df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())

# %%
df['LDAPS_PPT2'] = df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())

# %%
df['LDAPS_PPT3'] = df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())

# %%
df['LDAPS_PPT4'] = df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())

# %%
df['Next_Tmax'] = df['Next_Tmax'].fillna(df['Next_Tmax'].mean())

# %%
df['Next_Tmin'] = df['Next_Tmin'].fillna(df['Next_Tmin'].mean())

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     12.996904     29.768211     29.768211    56.759372    88.374804
# std       7.213213      2.956557      2.956557    14.596973     7.157124
# min       1.000000     20.000000     20.000000    19.794666    58.936283
# 25%       7.000000     27.800000     27.800000    46.046162    84.316923
# 50%      13.000000     29.900000     29.900000    55.313244    89.699505
# 75%      19.000000     32.000000     32.000000    67.038254    93.704500
# max      25.000000     37.600000     37.600000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.932898          2.333973     2.173245    33.567001
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.693091         22.114651     5.686487    37.532764
# 50%           29.662273         23.735942     6.563068    57.310630
# 75%           31.683819         25.134000     8.007471    83.904586
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7752.000000  ...  7752.000000  7752.000000  7752.000000  7752.000000
# mean      0.368774  ...     0.485003     0.278200     0.269407    37.544722
# std       0.261185  ...     1.754258     1.156174     1.200364     0.050352
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.148321  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.320110  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.571696  ...     0.024276     0.009697     0.000693    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7752.000000  7752.000000  7752.000000      7752.000000  7752.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.122557
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
#          Next_Tmin
# count  7752.000000
# mean     22.932220
# std       2.483276
# min      11.300000
# 25%      21.400000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for columns in df:
    if plotnumber<=25:
        ax= plt.subplot(5,5,plotnumber)
        sns.distplot(df[columns])
        plt.xlabel(columns, fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# station             0.000100
# Present_Tmax       -0.264137
# Present_Tmin       -0.264137
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.855015
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_WS            1.579236
# LDAPS_LH            0.673757
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3           0.640735
# LDAPS_CC4           0.666482
# LDAPS_PPT1          5.393821
# LDAPS_PPT2          5.775355
# LDAPS_PPT3          6.457129
# LDAPS_PPT4          6.825464
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.340200
# Next_Tmin          -0.404447
# dtype: float64

# %%
df['LDAPS_RHmax']= np.cbrt(df['LDAPS_RHmax'])

# %%
df['LDAPS_Tmin_lapse']= np.cbrt(df['LDAPS_Tmin_lapse'])

# %%
df['LDAPS_WS']= np.cbrt(df['LDAPS_WS'])

# %%
df['LDAPS_LH']= np.cbrt(df['LDAPS_LH'])

# %%
df['LDAPS_CC3']= np.cbrt(df['LDAPS_CC3'])

# %%
df['LDAPS_CC4']= np.cbrt(df['LDAPS_CC4'])

# %%
df['LDAPS_PPT1']= np.cbrt(df['LDAPS_PPT1'])

# %%
df['LDAPS_PPT2']= np.cbrt(df['LDAPS_PPT2'])

# %%
df['LDAPS_PPT3']= np.cbrt(df['LDAPS_PPT3'])

# %%
df['LDAPS_PPT4']= np.cbrt(df['LDAPS_PPT4'])

# %%
df['DEM']= np.cbrt(df['DEM'])

# %%
df['Slope']= np.cbrt(df['Slope'])

# %%
df.skew()
# Out:
# station             0.000100
# Present_Tmax       -0.264137
# Present_Tmin       -0.264137
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -1.003054
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.826395
# LDAPS_WS            0.884657
# LDAPS_LH           -0.414152
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3          -0.570388
# LDAPS_CC4          -0.466712
# LDAPS_PPT1          1.922841
# LDAPS_PPT2          2.223126
# LDAPS_PPT3          2.523911
# LDAPS_PPT4          2.792122
# lat                 0.087062
# lon                -0.285213
# DEM                 0.919779
# Slope               0.614110
# Solar radiation    -0.511210
# Next_Tmax          -0.340200
# Next_Tmin          -0.404447
# dtype: float64

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for columns in df:
    if plotnumber<=25:
        ax= plt.subplot(5,5,plotnumber)
        sns.distplot(df[columns])
        plt.xlabel(columns, fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
from scipy.stats import zscore
z_score= zscore(df[['LDAPS_RHmax','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_CC3','LDAPS_PPT1','LDAPS_PPT2',
                   'LDAPS_PPT3','LDAPS_PPT4','DEM','Slope']])
abs_z_score= np.abs(z_score)
filtering_entry= (abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (6852, 25)

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  6852.000000   6852.000000   6852.000000  6852.000000  6852.000000
# mean     12.997081     29.939010     29.939010    55.464133     4.447293
# std       7.190324      2.859791      2.859791    13.760063     0.117517
# min       1.000000     20.400000     20.400000    19.794666     4.082330
# 25%       7.000000     28.100000     28.100000    45.639254     4.379358
# 50%      13.000000     30.000000     30.000000    54.217558     4.467813
# 75%      19.000000     32.100000     32.100000    64.854614     4.537694
# max      25.000000     37.600000     37.600000    96.933922     4.641573
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       6852.000000       6852.000000  6852.000000  6852.000000
# mean          29.901000          2.867468     1.887252     3.826539
# std            2.719561          0.091044     0.163444     0.760024
# min           21.195428          2.569497     1.423182    -2.046338
# 25%           28.051822          2.811568     1.778607     3.324169
# 50%           29.914113          2.878061     1.862165     3.860681
# 75%           31.810723          2.931470     1.976869     4.392555
# max           38.542255          3.094034     2.444713     5.975959
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  6852.000000  ...  6852.000000  6852.000000  6852.000000  6852.000000
# mean      0.343597  ...     0.182430     0.132278     0.107927    37.544178
# std       0.249895  ...     0.365124     0.277567     0.258496     0.050229
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.137130  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.296536  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.498692  ...     0.178356     0.119528     0.000000    37.577600
# max       0.959130  ...     1.745620     1.419642     1.375268    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  6852.000000  6852.000000  6852.000000      6852.000000  6852.000000
# mean    126.990782     3.690594     0.950237      5343.396601    30.572106
# std       0.079861     0.972792     0.356035       418.901777     2.930344
# min     126.826000     2.312721     0.461826      4371.684570    20.700000
# 25%     126.937000     3.061686     0.647366      5019.721802    28.600000
# 50%     126.995000     3.575659     0.851784      5429.587402    30.800000
# 75%     127.042000     3.911219     1.209143      5719.299805    32.800000
# max     127.135000     5.965871     1.730054      5992.895996    38.900000
#
#          Next_Tmin
# count  6852.000000
# mean     23.076796
# std       2.378928
# min      13.300000
# 25%      21.500000
# 50%      23.200000
# 75%      24.700000
# max      29.800000
#
# [8 rows x 24 columns]

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for columns in df:
    if plotnumber<=25:
        ax= plt.subplot(5,5,plotnumber)
        sns.distplot(df[columns])
        plt.xlabel(columns, fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
df.skew()
# Out:
# station             0.003758
# Present_Tmax       -0.299738
# Present_Tmin       -0.299738
# LDAPS_RHmin         0.299430
# LDAPS_RHmax        -0.765250
# LDAPS_Tmax_lapse   -0.096095
# LDAPS_Tmin_lapse   -0.547123
# LDAPS_WS            0.670480
# LDAPS_LH           -0.255901
# LDAPS_CC1           0.602466
# LDAPS_CC2           0.506521
# LDAPS_CC3          -0.562310
# LDAPS_CC4          -0.417850
# LDAPS_PPT1          1.879906
# LDAPS_PPT2          2.232366
# LDAPS_PPT3          2.360175
# LDAPS_PPT4          2.695120
# lat                 0.097377
# lon                -0.276358
# DEM                 0.923844
# Slope               0.613941
# Solar radiation    -0.512667
# Next_Tmax          -0.269589
# Next_Tmin          -0.297650
# dtype: float64

# %%
df_corr= df.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(df_corr, annot=True, annot_kws={'size':10})
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df['Date'].nunique()
# Out:
# 299

# %%
df['Date']= df['Date'].astype(object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE= OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]= OE.fit_transform(df[i].values.reshape(-1,1))
        
df
# Out:
#       station   Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   10.0          28.7          28.7    58.255688     4.499858
# 1         2.0   10.0          31.9          31.9    52.263397     4.491419
# 2         3.0   10.0          31.6          31.6    48.690479     4.379060
# 3         4.0   10.0          32.0          32.0    58.239788     4.586534
# 4         5.0   10.0          31.4          31.4    56.174095     4.483978
# ...       ...    ...           ...           ...          ...          ...
# 7745     21.0  290.0          23.1          23.1    24.688997     4.277426
# 7746     22.0  290.0          22.5          22.5    30.094858     4.374125
# 7747     23.0  290.0          23.3          23.3    26.741310     4.288483
# 7748     24.0  290.0          23.3          23.3    24.040634     4.259746
# 7749     25.0  290.0          23.2          23.2    22.933014     4.258805
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_PPT2  \
# 0            28.074101          2.844153  1.896289  4.110499  ...         0.0
# 1            29.850689          2.885901  1.785468  3.731014  ...         0.0
# 2            30.091292          2.906984  1.830969  2.740099  ...         0.0
# 3            29.704629          2.857247  1.781083  4.035663  ...         0.0
# 4            29.113934          2.863778  1.789965  4.761697  ...         0.0
# ...                ...               ...       ...       ...  ...         ...
# 7745         27.812697          2.635366  1.876086  2.126355  ...         0.0
# 7746         26.704905          2.611685  1.793400  4.347071  ...         0.0
# 7747         26.352081          2.657859  1.832031  4.161290  ...         0.0
# 7748         27.010193          2.655868  1.870345  3.614996  ...         0.0
# 7749         27.939516          2.645880  1.938926  2.086997  ...         0.0
#
#       LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM     Slope  \
# 0            0.0         0.0  37.6046  126.991  5.965871  1.406938
# 1            0.0         0.0  37.6046  127.032  3.550622  0.801092
# 2            0.0         0.0  37.5776  127.058  3.217444  0.643203
# 3            0.0         0.0  37.6450  127.022  3.575659  1.363477
# 4            0.0         0.0  37.5507  127.135  3.272250  0.796600
# ...          ...         ...      ...      ...       ...       ...
# 7745         0.0         0.0  37.5507  127.040  2.973771  0.830151
# 7746         0.0         0.0  37.5102  127.086  2.800629  0.510703
# 7747         0.0         0.0  37.5372  126.891  2.498004  0.537630
# 7748         0.0         0.0  37.5237  126.909  2.586099  0.605778
# 7749         0.0         0.0  37.5237  126.970  2.695484  0.647366
#
#       Solar radiation  Next_Tmax  Next_Tmin
# 0         5992.895996       29.1       21.2
# 1         5869.312500       30.5       22.5
# 2         5863.555664       31.1       23.9
# 3         5856.964844       31.7       24.3
# 4         5859.552246       31.2       22.5
# ...               ...        ...        ...
# 7745      4456.024414       27.6       17.7
# 7746      4441.803711       28.0       17.1
# 7747      4443.313965       28.3       18.1
# 7748      4438.373535       28.6       18.8
# 7749      4451.345215       27.8       17.4
#
# [6852 rows x 25 columns]

# %%
df_corr= df.corr().abs()
plt.figure(figsize=(20,15))
sns.heatmap(df_corr, annot=True, annot_kws={'size':10})
plt.show()

# %%
X= df.drop('Next_Tmin', axis=1)
y=df['Next_Tmin']

# %%
scaler= StandardScaler()
x_scaled = scaler.fit_transform(X)

# %%
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X.columns
vif
# Out:
#          vif          Features
# 0   1.251468           station
# 1   1.112484              Date
# 2        inf      Present_Tmax
# 3        inf      Present_Tmin
# 4   5.876976       LDAPS_RHmin
# 5   2.221131       LDAPS_RHmax
# 6   7.905827  LDAPS_Tmax_lapse
# 7   5.997088  LDAPS_Tmin_lapse
# 8   1.264967          LDAPS_WS
# 9   1.512393          LDAPS_LH
# 10  4.721553         LDAPS_CC1
# 11  5.288853         LDAPS_CC2
# 12  3.725869         LDAPS_CC3
# 13  2.635483         LDAPS_CC4
# 14  2.645594        LDAPS_PPT1
# 15  2.168751        LDAPS_PPT2
# 16  1.594770        LDAPS_PPT3
# 17  1.578556        LDAPS_PPT4
# 18  1.237787               lat
# 19  1.185382               lon
# 20  3.074884               DEM
# 21  2.869962             Slope
# 22  1.228263   Solar radiation
# 23  3.858465         Next_Tmax

# %%
X.drop('LDAPS_Tmax_lapse', axis=1, inplace=True)

# %%
x_scaled = scaler.fit_transform(X)
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X.columns
vif
# Out:
#          vif          Features
# 0   1.245702           station
# 1   1.112270              Date
# 2        inf      Present_Tmax
# 3        inf      Present_Tmin
# 4   3.767131       LDAPS_RHmin
# 5   2.206999       LDAPS_RHmax
# 6   3.055741  LDAPS_Tmin_lapse
# 7   1.264838          LDAPS_WS
# 8   1.511863          LDAPS_LH
# 9   4.692833         LDAPS_CC1
# 10  5.202764         LDAPS_CC2
# 11  3.725863         LDAPS_CC3
# 12  2.631895         LDAPS_CC4
# 13  2.627224        LDAPS_PPT1
# 14  2.166771        LDAPS_PPT2
# 15  1.593664        LDAPS_PPT3
# 16  1.572541        LDAPS_PPT4
# 17  1.229329               lat
# 18  1.162029               lon
# 19  3.070744               DEM
# 20  2.860912             Slope
# 21  1.167458   Solar radiation
# 22  3.239184         Next_Tmax

# %%
X.drop('LDAPS_CC2',axis=1, inplace=True)

# %%
x_scaled = scaler.fit_transform(X)
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X.columns
vif
# Out:
#          vif          Features
# 0   1.245606           station
# 1   1.106839              Date
# 2        inf      Present_Tmax
# 3        inf      Present_Tmin
# 4   3.546104       LDAPS_RHmin
# 5   2.198250       LDAPS_RHmax
# 6   3.054772  LDAPS_Tmin_lapse
# 7   1.264828          LDAPS_WS
# 8   1.455290          LDAPS_LH
# 9   3.489558         LDAPS_CC1
# 10  3.475823         LDAPS_CC3
# 11  2.631759         LDAPS_CC4
# 12  2.452074        LDAPS_PPT1
# 13  1.801485        LDAPS_PPT2
# 14  1.592920        LDAPS_PPT3
# 15  1.562032        LDAPS_PPT4
# 16  1.226449               lat
# 17  1.160331               lon
# 18  3.070702               DEM
# 19  2.856515             Slope
# 20  1.163955   Solar radiation
# 21  3.187029         Next_Tmax

# %%
X.drop('Present_Tmax', axis=1, inplace=True)

# %%
x_scaled = scaler.fit_transform(X)
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X.columns
vif
# Out:
#          vif          Features
# 0   1.245606           station
# 1   1.106839              Date
# 2   2.397807      Present_Tmin
# 3   3.546104       LDAPS_RHmin
# 4   2.198250       LDAPS_RHmax
# 5   3.054772  LDAPS_Tmin_lapse
# 6   1.264828          LDAPS_WS
# 7   1.455290          LDAPS_LH
# 8   3.489558         LDAPS_CC1
# 9   3.475823         LDAPS_CC3
# 10  2.631759         LDAPS_CC4
# 11  2.452074        LDAPS_PPT1
# 12  1.801485        LDAPS_PPT2
# 13  1.592920        LDAPS_PPT3
# 14  1.562032        LDAPS_PPT4
# 15  1.226449               lat
# 16  1.160331               lon
# 17  3.070702               DEM
# 18  2.856515             Slope
# 19  1.163955   Solar radiation
# 20  3.187029         Next_Tmax

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor , RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
maxAccu=0
maxRS=0
for i in range(1,300):
    x_train,x_test,y_train,y_test= train_test_split(X,y,test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is", maxAccu,"on random_state ", maxRS)
# Out:
# Maximum r2 score is 0.8363263111278932 on random_state  152

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=maxRS)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2_score ", r2_score(y_test, predLR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predLR))
print("Mean squared error ", mean_squared_error(y_test,predLR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predLR)))
# Out:
# R2_score  0.8363263111278932
# R2_score on training data  81.33038084941816
# Mean Absolute Error  0.7766778585505391
# Mean squared error  0.9650489156396314
# Root mean squared error  0.9823690323089543

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, predLR)
plt.plot(predLR, predLR)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual v/s predicted model')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predRFR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predRFR))
print("Mean squared error ", mean_squared_error(y_test,predRFR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predRFR)))
# Out:
# R2_score  0.9139823799086112
# R2_score on training data  98.58280360747278
# Mean Absolute Error  0.5405480461430603
# Mean squared error  0.5071750479086519
# Root mean squared error  0.7121622342617249

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2_score ", r2_score(y_test, predknn))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predknn))
print("Mean squared error ", mean_squared_error(y_test,predknn))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predknn)))
# Out:
# R2_score  0.7102144432187353
# R2_score on training data  81.14307209379305
# Mean Absolute Error  0.9365310049358062
# Mean squared error  1.7086267149407754
# Root mean squared error  1.3071444889302695

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2_score ", r2_score(y_test, predGBR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predGBR))
print("Mean squared error ", mean_squared_error(y_test,predGBR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predGBR)))
# Out:
# R2_score  0.8981716732823649
# R2_score on training data  90.54969846967126
# Mean Absolute Error  0.5973607195473939
# Mean squared error  0.6003977606751363
# Root mean squared error  0.7748533801146745

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
predlasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2_score ", r2_score(y_test, predlasso))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predlasso))
print("Mean squared error ", mean_squared_error(y_test,predlasso))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predlasso)))
# Out:
# R2_score  0.5687654142263496
# R2_score on training data  56.845743180170835
# Mean Absolute Error  1.2635496918334546
# Mean squared error  2.542635119028525
# Root mean squared error  1.5945642411105692

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
predridge=ridge.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predridge))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predridge))
print("Mean squared error ", mean_squared_error(y_test,predridge))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predridge)))
# Out:
# R2_score  0.8354062691139723
# R2_score on training data  98.58280360747278
# Mean Absolute Error  0.7786847974948735
# Mean squared error  0.9704736455030312
# Root mean squared error  0.9851262079058861

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2_score ", r2_score(y_test, predDTR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predDTR))
print("Mean squared error ", mean_squared_error(y_test,predDTR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predDTR)))
# Out:
# R2_score  0.8091682411493804
# R2_score on training data  100.0
# Mean Absolute Error  0.7841956382674873
# Mean squared error  1.1251776826041768
# Root mean squared error  1.0607439288556766

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2_score ", r2_score(y_test, predsvr))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predsvr))
print("Mean squared error ", mean_squared_error(y_test,predsvr))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predsvr)))
# Out:
# R2_score  0.08623132595782035
# R2_score on training data  8.734358107818885
# Mean Absolute Error  1.8179973493728112
# Mean squared error  5.387741145853472
# Root mean squared error  2.3211508235902016

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2_score ", r2_score(y_test, predETR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predETR))
print("Mean squared error ", mean_squared_error(y_test,predETR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predETR)))
# Out:
# R2_score  0.9198671383176631
# R2_score on training data  100.0
# Mean Absolute Error  0.513625243001707
# Mean squared error  0.4724774751919135
# Root mean squared error  0.6873699696611087

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(RFR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predRFR)-score.mean())*100)
# Out:
# [0.72197072 0.70182517 0.8265911  0.84037214 0.85591638]
# 0.7893351027244588
# The difference between R2 score and CV score is  12.464727718415237

# %%
score = cross_val_score(LR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predLR)-score.mean())*100)
# Out:
# [0.71829309 0.67591615 0.79368091 0.80609281 0.83939087]
# 0.7666747673691688
# The difference between R2 score and CV score is  6.96515437587244

# %%
score = cross_val_score(ridge,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predridge)-score.mean())*100)
# Out:
# [0.71637068 0.67744265 0.79098652 0.80580328 0.83794481]
# 0.7657095878670371
# The difference between R2 score and CV score is  6.969668124693518

# %%
score = cross_val_score(lasso,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predlasso)-score.mean())*100)
# Out:
# [-0.0277136   0.33467735  0.50021367  0.57026811  0.57796409]
# 0.39108192131144853
# The difference between R2 score and CV score is  17.76834929149011

# %%
score = cross_val_score(GBR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predGBR)-score.mean())*100)
# Out:
# [0.72776481 0.70634414 0.83785761 0.84976454 0.8601626 ]
# 0.7963787419501541
# The difference between R2 score and CV score is  10.17929313322108

# %%
score = cross_val_score(knn,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predknn)-score.mean())*100)
# Out:
# [-1.06990746 -0.37071363 -0.68085895 -0.10785502  0.21610688]
# -0.4026456360821674
# The difference between R2 score and CV score is  111.28600793009026

# %%
score = cross_val_score(DTR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predDTR)-score.mean())*100)
# Out:
# [0.38624809 0.47788118 0.67044212 0.74718332 0.62408654]
# 0.5811682513863851
# The difference between R2 score and CV score is  22.79999897629953

# %%
score = cross_val_score(svr,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predsvr)-score.mean())*100)
# Out:
# [-0.39223514 -0.50855559 -0.0455517  -0.03877133  0.08239898]
# -0.18054295634926817
# The difference between R2 score and CV score is  26.677428230708855

# %%
score = cross_val_score(ETR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predETR)-score.mean())*100)
# Out:
# [0.72486706 0.69991095 0.82219743 0.84243784 0.87466108]
# 0.7928148723253859
# The difference between R2 score and CV score is  12.705226599227714

# %%
parameters={'n_estimators':[500,1000,2000],'learning_rate':[.001,0.01,.1],'max_depth':[1,2,4],'subsample':[.5,.75,1],'random_state':[1]}

# %%
from sklearn.model_selection import  GridSearchCV

# %%
GCV= GridSearchCV(GradientBoostingRegressor(), parameters, cv=5)

# %%
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [1, 2, 4],
#                          'n_estimators': [500, 1000, 2000], 'random_state': [1],
#                          'subsample': [0.5, 0.75, 1]})

# %%
GCV.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 4,
#  'n_estimators': 2000,
#  'random_state': 1,
#  'subsample': 0.75}

# %%
Final_model = GradientBoostingRegressor(learning_rate= 0.1,
 max_depth= 4,
 n_estimators= 2000,
 random_state= 1,
 subsample=0.75)

# %%
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
R2_score= r2_score(y_test,pred)
print(R2_score*100)
# Out:
# 95.10731656666958

# %%
import pickle
filename = 'MIN_Temperature_dataset.pkl'
pickle.dump(Final_model, open(filename, 'wb'))

# %%
loaded_model= pickle.load(open('MIN_Temperature_dataset.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 95.10731656666958

# %%
#for Next_Tmax

# %%
df
# Out:
#       station   Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   10.0          28.7          28.7    58.255688     4.499858
# 1         2.0   10.0          31.9          31.9    52.263397     4.491419
# 2         3.0   10.0          31.6          31.6    48.690479     4.379060
# 3         4.0   10.0          32.0          32.0    58.239788     4.586534
# 4         5.0   10.0          31.4          31.4    56.174095     4.483978
# ...       ...    ...           ...           ...          ...          ...
# 7745     21.0  290.0          23.1          23.1    24.688997     4.277426
# 7746     22.0  290.0          22.5          22.5    30.094858     4.374125
# 7747     23.0  290.0          23.3          23.3    26.741310     4.288483
# 7748     24.0  290.0          23.3          23.3    24.040634     4.259746
# 7749     25.0  290.0          23.2          23.2    22.933014     4.258805
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_PPT2  \
# 0            28.074101          2.844153  1.896289  4.110499  ...         0.0
# 1            29.850689          2.885901  1.785468  3.731014  ...         0.0
# 2            30.091292          2.906984  1.830969  2.740099  ...         0.0
# 3            29.704629          2.857247  1.781083  4.035663  ...         0.0
# 4            29.113934          2.863778  1.789965  4.761697  ...         0.0
# ...                ...               ...       ...       ...  ...         ...
# 7745         27.812697          2.635366  1.876086  2.126355  ...         0.0
# 7746         26.704905          2.611685  1.793400  4.347071  ...         0.0
# 7747         26.352081          2.657859  1.832031  4.161290  ...         0.0
# 7748         27.010193          2.655868  1.870345  3.614996  ...         0.0
# 7749         27.939516          2.645880  1.938926  2.086997  ...         0.0
#
#       LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM     Slope  \
# 0            0.0         0.0  37.6046  126.991  5.965871  1.406938
# 1            0.0         0.0  37.6046  127.032  3.550622  0.801092
# 2            0.0         0.0  37.5776  127.058  3.217444  0.643203
# 3            0.0         0.0  37.6450  127.022  3.575659  1.363477
# 4            0.0         0.0  37.5507  127.135  3.272250  0.796600
# ...          ...         ...      ...      ...       ...       ...
# 7745         0.0         0.0  37.5507  127.040  2.973771  0.830151
# 7746         0.0         0.0  37.5102  127.086  2.800629  0.510703
# 7747         0.0         0.0  37.5372  126.891  2.498004  0.537630
# 7748         0.0         0.0  37.5237  126.909  2.586099  0.605778
# 7749         0.0         0.0  37.5237  126.970  2.695484  0.647366
#
#       Solar radiation  Next_Tmax  Next_Tmin
# 0         5992.895996       29.1       21.2
# 1         5869.312500       30.5       22.5
# 2         5863.555664       31.1       23.9
# 3         5856.964844       31.7       24.3
# 4         5859.552246       31.2       22.5
# ...               ...        ...        ...
# 7745      4456.024414       27.6       17.7
# 7746      4441.803711       28.0       17.1
# 7747      4443.313965       28.3       18.1
# 7748      4438.373535       28.6       18.8
# 7749      4451.345215       27.8       17.4
#
# [6852 rows x 25 columns]

# %%
X1= df.drop('Next_Tmax', axis=1)
y1=df['Next_Tmax']

# %%
scaler1= StandardScaler()
x_scaled = scaler1.fit_transform(X1)

# %%
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X1.columns
vif
# Out:
#          vif          Features
# 0   1.241558           station
# 1   1.113041              Date
# 2        inf      Present_Tmax
# 3        inf      Present_Tmin
# 4   5.922541       LDAPS_RHmin
# 5   2.228572       LDAPS_RHmax
# 6   6.705422  LDAPS_Tmax_lapse
# 7   8.171928  LDAPS_Tmin_lapse
# 8   1.266576          LDAPS_WS
# 9   1.482910          LDAPS_LH
# 10  4.708541         LDAPS_CC1
# 11  5.270780         LDAPS_CC2
# 12  3.719595         LDAPS_CC3
# 13  2.576145         LDAPS_CC4
# 14  2.640575        LDAPS_PPT1
# 15  2.172549        LDAPS_PPT2
# 16  1.594759        LDAPS_PPT3
# 17  1.580233        LDAPS_PPT4
# 18  1.240745               lat
# 19  1.178019               lon
# 20  3.268417               DEM
# 21  2.924883             Slope
# 22  1.230892   Solar radiation
# 23  4.823442         Next_Tmin

# %%
X1.drop('LDAPS_Tmin_lapse', axis=1, inplace=True)

# %%
x_scaled = scaler.fit_transform(X1)
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X1.columns
vif
# Out:
#          vif          Features
# 0   1.241079           station
# 1   1.106928              Date
# 2        inf      Present_Tmax
# 3        inf      Present_Tmin
# 4   4.572718       LDAPS_RHmin
# 5   2.205238       LDAPS_RHmax
# 6   4.094094  LDAPS_Tmax_lapse
# 7   1.263279          LDAPS_WS
# 8   1.410015          LDAPS_LH
# 9   4.555558         LDAPS_CC1
# 10  5.244961         LDAPS_CC2
# 11  3.717211         LDAPS_CC3
# 12  2.576142         LDAPS_CC4
# 13  2.619004        LDAPS_PPT1
# 14  2.169350        LDAPS_PPT2
# 15  1.593434        LDAPS_PPT3
# 16  1.567143        LDAPS_PPT4
# 17  1.234669               lat
# 18  1.174935               lon
# 19  3.175856               DEM
# 20  2.833990             Slope
# 21  1.218925   Solar radiation
# 22  3.523734         Next_Tmin

# %%
X1.drop('LDAPS_CC2', axis=1, inplace=True)

# %%
x_scaled = scaler.fit_transform(X1)
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X1.columns
vif
# Out:
#          vif          Features
# 0   1.241056           station
# 1   1.100024              Date
# 2        inf      Present_Tmax
# 3        inf      Present_Tmin
# 4   4.453552       LDAPS_RHmin
# 5   2.195964       LDAPS_RHmax
# 6   3.987529  LDAPS_Tmax_lapse
# 7   1.263272          LDAPS_WS
# 8   1.339143          LDAPS_LH
# 9   3.331526         LDAPS_CC1
# 10  3.467587         LDAPS_CC3
# 11  2.575999         LDAPS_CC4
# 12  2.455126        LDAPS_PPT1
# 13  1.805987        LDAPS_PPT2
# 14  1.592589        LDAPS_PPT3
# 15  1.556641        LDAPS_PPT4
# 16  1.232719               lat
# 17  1.170955               lon
# 18  3.175308               DEM
# 19  2.826499             Slope
# 20  1.217673   Solar radiation
# 21  3.504549         Next_Tmin

# %%
X1.drop('Present_Tmin', axis=1, inplace=True)

# %%
x_scaled = scaler.fit_transform(X1)
x_scaled.shape[1]
vif = pd.DataFrame()
vif['vif']= [variance_inflation_factor(x_scaled, i) for i in range(x_scaled.shape[1])]
vif['Features']= X1.columns
vif
# Out:
#          vif          Features
# 0   1.241056           station
# 1   1.100024              Date
# 2   2.253077      Present_Tmax
# 3   4.453552       LDAPS_RHmin
# 4   2.195964       LDAPS_RHmax
# 5   3.987529  LDAPS_Tmax_lapse
# 6   1.263272          LDAPS_WS
# 7   1.339143          LDAPS_LH
# 8   3.331526         LDAPS_CC1
# 9   3.467587         LDAPS_CC3
# 10  2.575999         LDAPS_CC4
# 11  2.455126        LDAPS_PPT1
# 12  1.805987        LDAPS_PPT2
# 13  1.592589        LDAPS_PPT3
# 14  1.556641        LDAPS_PPT4
# 15  1.232719               lat
# 16  1.170955               lon
# 17  3.175308               DEM
# 18  2.826499             Slope
# 19  1.217673   Solar radiation
# 20  3.504549         Next_Tmin

# %%
maxAccu=0
maxRS=0
for i in range(1,300):
    x_train,x_test,y_train,y_test= train_test_split(X1,y1,test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is", maxAccu,"on random_state ", maxRS)
# Out:
# Maximum r2 score is 0.7910766463295099 on random_state  280

# %%
x_train, x_test, y_train, y_test = train_test_split(X1,y1, test_size=0.20, random_state=maxRS)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2_score ", r2_score(y_test, predLR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predLR))
print("Mean squared error ", mean_squared_error(y_test,predLR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predLR)))
# Out:
# R2_score  0.7910766463295099
# R2_score on training data  76.20760921675279
# Mean Absolute Error  1.0488120672423678
# Mean squared error  1.8388683760156783
# Root mean squared error  1.3560488103367365

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, predLR)
plt.plot(predLR, predLR)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual v/s predicted model')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predRFR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predRFR))
print("Mean squared error ", mean_squared_error(y_test,predRFR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predRFR)))
# Out:
# R2_score  0.9099469491714466
# R2_score on training data  98.54748370734046
# Mean Absolute Error  0.6702345199568502
# Mean squared error  0.7926146331804234
# Root mean squared error  0.890289072818724

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2_score ", r2_score(y_test, predknn))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predknn))
print("Mean squared error ", mean_squared_error(y_test,predknn))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predknn)))
# Out:
# R2_score  0.7566608604027935
# R2_score on training data  83.18869226523901
# Mean Absolute Error  1.0236359164288462
# Mean squared error  2.1417837718511192
# Root mean squared error  1.4634834375048866

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2_score ", r2_score(y_test, predGBR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predGBR))
print("Mean squared error ", mean_squared_error(y_test,predGBR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predGBR)))
# Out:
# R2_score  0.8701825422182304
# R2_score on training data  87.76460165121833
# Mean Absolute Error  0.8362547723743224
# Mean squared error  1.1426066716607792
# Root mean squared error  1.068927814055177

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
predlasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2_score ", r2_score(y_test, predlasso))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predlasso))
print("Mean squared error ", mean_squared_error(y_test,predlasso))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predlasso)))
# Out:
# R2_score  0.7027189357348893
# R2_score on training data  67.24431893687985
# Mean Absolute Error  1.259531121701466
# Mean squared error  2.6165612329178836
# Root mean squared error  1.6175788181470119

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
predridge=ridge.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predridge))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predridge))
print("Mean squared error ", mean_squared_error(y_test,predridge))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predridge)))
# Out:
# R2_score  0.7911969235663268
# R2_score on training data  98.54748370734046
# Mean Absolute Error  1.0483759818567666
# Mean squared error  1.8378097389449473
# Root mean squared error  1.3556584152893927

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2_score ", r2_score(y_test, predDTR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predDTR))
print("Mean squared error ", mean_squared_error(y_test,predDTR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predDTR)))
# Out:
# R2_score  0.7868621191758657
# R2_score on training data  100.0
# Mean Absolute Error  0.999197665937272
# Mean squared error  1.8759631314201832
# Root mean squared error  1.369658034481667

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2_score ", r2_score(y_test, predsvr))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predsvr))
print("Mean squared error ", mean_squared_error(y_test,predsvr))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predsvr)))
# Out:
# R2_score  0.038942284478788336
# R2_score on training data  3.5971926833432533
# Mean Absolute Error  2.3164079536631954
# Mean squared error  8.458885086562006
# Root mean squared error  2.9084162505669657

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2_score ", r2_score(y_test, predETR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predETR))
print("Mean squared error ", mean_squared_error(y_test,predETR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predETR)))
# Out:
# R2_score  0.9225923956785906
# R2_score on training data  100.0
# Mean Absolute Error  0.6229867254903346
# Mean squared error  0.6813139514995238
# Root mean squared error  0.8254174407531766

# %%
score = cross_val_score(RFR,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predRFR)-score.mean())*100)
# Out:
# [0.67079974 0.68055806 0.69348407 0.73103724 0.5626053 ]
# 0.6676968811351338
# The difference between R2 score and CV score is  24.225006803631278

# %%
score = cross_val_score(LR,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predLR)-score.mean())*100)
# Out:
# [0.70191435 0.67578937 0.6899508  0.72575835 0.58394323]
# 0.6754712211737941
# The difference between R2 score and CV score is  11.560542515571582

# %%
score = cross_val_score(ridge,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predridge)-score.mean())*100)
# Out:
# [0.70157571 0.67632267 0.69019158 0.72582605 0.58370038]
# 0.6755232780940748
# The difference between R2 score and CV score is  11.5673645472252

# %%
score = cross_val_score(lasso,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predlasso)-score.mean())*100)
# Out:
# [0.60592033 0.60533149 0.65059104 0.64067324 0.48618232]
# 0.597739684538284
# The difference between R2 score and CV score is  10.497925119660534

# %%
score = cross_val_score(GBR,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predGBR)-score.mean())*100)
# Out:
# [0.70853808 0.69412341 0.72014655 0.77566015 0.60597594]
# 0.7008888255261722
# The difference between R2 score and CV score is  16.92937166920583

# %%
score = cross_val_score(knn,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predknn)-score.mean())*100)
# Out:
# [-0.93270303 -0.62486982 -0.57282715 -0.53577649 -0.3694528 ]
# -0.6071258571783359
# The difference between R2 score and CV score is  136.37867175811294

# %%
score = cross_val_score(DTR,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predDTR)-score.mean())*100)
# Out:
# [0.3527561  0.25989431 0.37253984 0.58066908 0.29011558]
# 0.3711949843178033
# The difference between R2 score and CV score is  41.56671348580624

# %%
score = cross_val_score(svr,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predsvr)-score.mean())*100)
# Out:
# [-0.01417688 -0.32699472  0.01469537 -0.22720453 -0.15404763]
# -0.14154567831286885
# The difference between R2 score and CV score is  18.048796279165717

# %%
score = cross_val_score(ETR,X1,y1)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predETR)-score.mean())*100)
# Out:
# [0.72017283 0.6614091  0.72002741 0.74638671 0.58491817]
# 0.6865828443295954
# The difference between R2 score and CV score is  23.600955134899525

# %%
parameters1={'n_estimators':[500,1000,2000],'learning_rate':[.001,0.01,.1],'max_depth':[1,2,4],'subsample':[.5,.75,1],'random_state':[1]}

# %%
GCV= GridSearchCV(GradientBoostingRegressor(), parameters1, cv=5)

# %%
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [1, 2, 4],
#                          'n_estimators': [500, 1000, 2000], 'random_state': [1],
#                          'subsample': [0.5, 0.75, 1]})

# %%
GCV.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 4,
#  'n_estimators': 2000,
#  'random_state': 1,
#  'subsample': 0.75}

# %%
Final_model = GradientBoostingRegressor(learning_rate=0.1,
 max_depth =4,
 n_estimators= 2000,
random_state= 1,
subsample= 0.75)

# %%
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
R2_score= r2_score(y_test,pred)
print(R2_score*100)
# Out:
# 94.30157205932674

# %%
import pickle
filename = 'MAX_Temperature_dataset.pkl'
pickle.dump(Final_model, open(filename, 'wb'))

# %%
loaded_model= pickle.load(open('MAX_Temperature_dataset.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 94.30157205932674
